# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/Troubleshooting Dialogue/tech_support_dataset.csv")
df1.head()
# Out:
#   Conversation_ID                 Customer_Issue  \
# 0       CONV-0001        Cannot connect to Wi-Fi
# 1       CONV-0002  Software installation failure
# 2       CONV-0003        Cannot connect to Wi-Fi
# 3       CONV-0004                Forgot password
# 4       CONV-0005  Software installation failure
#
#                                   Tech_Response Resolution_Time  \
# 0  Clear cache and remove unnecessary programs.      92 minutes
# 1                Reinstall the printer drivers.      76 minutes
# 2  Clear cache and remove unnecessary programs.      50 minutes
# 3  Reset your password using the link provided.      97 minutes
# 4       Follow the software installation guide.     110 minutes
#
#   Issue_Category Issue_Status
# 0       Software      Pending
# 1        Account      Pending
# 2        Network     Resolved
# 3    Performance      Pending
# 4    Performance      Pending

# %%
df2 = pd.read_csv("data/Routing Engine/all_tickets_processed_improved_v3.csv")
df2.head()
# Out:
#                                             Document    Topic_group
# 0  connection with icon icon dear please setup ic...       Hardware
# 1  work experience user work experience user hi w...         Access
# 2  requesting for meeting requesting meeting hi p...       Hardware
# 3  reset passwords for external accounts re expir...         Access
# 4  mail verification warning hi has got attached ...  Miscellaneous

# %%
df3 = pd.read_csv("data/Routing Engine/customer_support_tickets.csv")
df3.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# ...

# %%
df4  = pd.read_csv("data/Routing Engine/IT Support Ticket Data.csv")
df4.head()
# Out:
#    Unnamed: 0                                               Body  \
# 0           0  Dear Customer Support Team,I am writing to rep...
# 1           1  Dear Customer Support Team,I hope this message...
# 2           2  Dear Customer Support Team,I hope this message...
# 3           3  Dear Support Team,I hope this message reaches ...
# 4           4  Dear Customer Support,I hope this message reac...
#
#               Department Priority  \
# 0      Technical Support     high
# 1  Returns and Exchanges   medium
# 2   Billing and Payments      low
# 3    Sales and Pre-Sales   medium
# 4      Technical Support     high
#
#                                                 Tags
# 0  ['Account', 'Disruption', 'Outage', 'IT', 'Tec...
# 1             ['Product', 'Feature', 'Tech Support']
# 2  ['Billing', 'Payment', 'Account', 'Documentati...
# 3  ['Product', 'Feature', 'Feedback', 'Tech Suppo...
# 4  ['Feature', 'Product', 'Documentation', 'Feedb...

# %%
df5  = pd.read_csv("data/Routing Engine/IT Support Ticket Data.csv")
df5.head()
